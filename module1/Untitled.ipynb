# %%
import os

# %%
import sys
# CRITICAL: Add paths for imports
# Add project root for shared_utils
sys.path.insert(0, os.path.abspath('..'))
# Add module1 for helpers
sys.path.insert(0, os.path.abspath('../module1'))

# %%
# Load model endpoint configuration from shared_utils.config
from shared_utils.config import MODEL_ENDPOINT_CONFIG

MODEL_ENDPOINT = MODEL_ENDPOINT_CONFIG.get("model_endpoint")
ACCESS_KEY = MODEL_ENDPOINT_CONFIG.get("access_key")

if not MODEL_ENDPOINT or not ACCESS_KEY:
    raise ValueError(
        "Missing model_endpoint or access_key in shared_utils/config.py\n"
        "Please update MODEL_ENDPOINT_CONFIG in shared_utils/config.py with your credentials."
    )

print(f"✓ Model endpoint loaded from shared_utils/config.py")
print(f"Model: {MODEL_ENDPOINT}")
# Out:
# ✓ Model endpoint loaded from shared_utils/config.py
# Model: https://modelservice.ml-56979638-3f1.go01-dem.ylcu-atmi.cloudera.site/model
